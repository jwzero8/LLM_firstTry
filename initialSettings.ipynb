# %%
import os, sys
import ipdb # debugging
from tqdm import tqdm # dat
from datetime import datetime # may use for checkpoint files for the state of training
import platform, shutil # detect platform type
import requests, zipfile, io


# Pytorch
import torch # library for deep learning
import torch.nn as nn # neuron network
from torch.nn import functional as F

# Tokenizer
import sentencepiece as spm # translate human language to tokens for computer to understand

# A-series GPU will benefit from this setting
#torch.backends.cuda.matmul.allow_tf32 = True
#torch.backends.cudnn.allow_tf32 = True

torch.cuda.empty_cache() # empty GPU cache
files_url = "https://ideami.com/llm_train"
print("Downloading files using Python")
response = requests.get(files_url) # GET request to fetch stuff from the website
zipfile.ZipFile(io.BytesIO(response.content)).extractall(".") # . indicate current folder
# Out:
# Downloading files using Python

# %%
# ARCHITECTURE PARAMETERS
batch_size = 32 # 8 to 128 and beyond, if only 4GB available for your GPU then make this 8 -- GPU for parallel computing
context = 512 # Sequence length aka focus window
embed_size = 384 # dimensions of vectors, this means 384 numbers to explain a token
n_layers = 7
n_heads = 7
BIAS = True

# Hyper parameters are the ones impacting the training process
lr = 3e-4
dropout = 0.05
weight_decay = 0.01
grad_clip = 1.0

# Training parameters
load_pretrained = True
train_iters = 100000
eval_interval = 50 # Every 50 times of iteration we are going to evaluate our data
eval_iters = 10 
compile = True
checkpoint_dir = "models/"
# checkpoint_fn = "lastest.pt"
checkpoint_fn = 'latest.pt' # File name for saving a checkpoint
# checkpoint_load_fn = "latest.pt"
checkpoint_load_fn = 'latest.pt' # File name for loading a checkpoint
dtype = torch.bfloat16

# Mode : False for training, True for getting output for use 
inference = True

# Device
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device: You will be using: ", device)
# Out:
# device: You will be using:  cuda

# %%
# Logging

wandb_log = True
wandb_project = "llm9"
# wandb_run_name = "llm1-" + datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
wandb_run_name = 'llm9run'

if wandb_log:
    import wandb # For deep-learning metrics visualizaiton
    wandb.init(project = wandb_project, name = wandb_run_name)

#wandb.finish() # This will finish the project
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: jwzero8 (jwzero8-the-university-of-hong-kong). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>C:\Users\ZGMF-X42S\Desktop\Computer Science learning resources (including grad school application materials)\Udemy\LLM Mastery Hands-on Code, Align and Master LLMs\Jupyter Environment_LLM\wandb\run-20241029_110200-9784pxnb</code>
# Syncing run <strong><a href='https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9/runs/9784pxnb' target="_blank">llm9run</a></strong> to <a href='https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9' target="_blank">https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9</a>
#  View run at <a href='https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9/runs/9784pxnb' target="_blank">https://wandb.ai/jwzero8-the-university-of-hong-kong/llm9/runs/9784pxnb</a>

# %%
# Load Data
with open('wiki.txt', 'r', encoding = 'utf-8') as f: #
    text = f.read()
print(text[30000:30300])
# Out:
# terms.
# For example, there are objects in two groups (as shown on the right). The objects are various shapes, where one group has 3 of them while the other has 2. When the two groups combine into one, the overall amount (sum) of the shapes become 5.
#
# Vertical Addition
#
# The animation above demonstrate

# %%
# Initialize Tokenizer

sp = spm.SentencePieceProcessor(model_file = 'wiki_tokenizer.model')

vocab_size = sp.get_piece_size()
print(f"Tokenizer vocab size: {vocab_size}")
# Out:
# Tokenizer vocab size: 4096

# %%
# Set up tokenizing function
encode = lambda s : sp.Encode(s)
decode = lambda l : sp.Decode(l)

print(encode('Once upon a time'))
print(decode(encode('Once upon a time')))
# Out:
# [612, 370, 698, 265, 261, 684]
# Once upon a time

# %%
# Tokenize our data or load tokenizer if pre-trained tokenizers are available
if os.path.exists('encoded_data.pt'):
    print('Loading Encoding')
    data = torch.load('encoded_data.pt')
else:
    data = torch.tensor(encode(text), dtype = torch.long) # dtype can be more accurate for better performacne yet more memory and computation power is required
    torch.save(data, 'encoded_data.pt')
# Out:
# Loading Encoding
# C:\Users\ZGMF-X42S\AppData\Local\Temp\ipykernel_2036\2177634386.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load('encoded_data.pt')

# %%
# Split data between traiing and evaluation datasets
data_size = len(data)
spl = int(0.9 * data_size)
train_data = data[:spl]
val_data = data[spl:]
print(f'Total size: {data_size/1e6:.2f} million | Training {len(train_data)/1e6:.2f} Million | Validation {len(val_data)/1e6:.2f} Million')
# Out:
# Total size: 59.21 million | Training 53.29 Million | Validation 5.92 Million

# %%
def get_batch(split):
    # BS = Batch Size (e.g. 32) / SL = Sequence or Context Length (e.g. 512)
    data = train_data if split == 'train' else val_data
    inds = torch.randint(len(data) - context, (batch_size,))
    x = torch.stack([data[i: i + context] for i in inds]) # (BS, SL) e.g. (32, 512)
    y = torch.stack([data[i + 1: i + context + 1] for i in inds])

    x,y = x.to(device), y.to(device)
    return x,y

x,y = get_batch("train")
print(x.shape, y.shape)
print(x[0][:10])
print(y[0][:10])
# Out:
# torch.Size([32, 512]) torch.Size([32, 512])
# tensor([ 410, 4051,  310,  353,  944,  836,  381, 4035,  307, 4031],
#        device='cuda:0')
# tensor([4051,  310,  353,  944,  836,  381, 4035,  307, 4031, 4056],
#        device='cuda:0')

# %%
class GPT(nn.Module):
    def __init__(self):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embed_size) # In our case will be from 4096 x 384
        self.positions = nn.Embedding(context, embed_size) # e.g. 512 x 384
        # Number of heads with multi-attention mechanism in each layer, which is 7 in this case
        self.blocks = nn.Sequential(*[Block(n_heads) for _ in range(n_layers)]) 
        self.ln = nn.LayerNorm(embed_size)
        self.final_linear = nn.Linear(embed_size, vocab_size, bias=BIAS) # e.g. 384 x 4906, {embeddings x vocab tokens/options}
        self.apply(self._init_weights)
    
    # parameter initialization
    def _init_weights(self, module):
        if isinstance(module, nn.Linear): # If it is linear layer
            torch.nn.init.normal_(module.weight, mean = 0.0, std = 0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)

        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean = 0.0, std = 0.02)


    def forward(self, input, targets = None):
        # BS = batch size, SL = Sequence or Context Length
        loss = None
        BS, SL = input.shape # BS x SL
        emb = self.embeddings(input) # BS x SL x Embed_size(384)
        pos = self.positions(torch.arange(SL, device = device)) # SL x 384
        x = emb + pos # BS x SL x 384
        x = self.blocks(x) # Pass our input to blocks, traverl through blocks and layers, BS x SL x 384
        x = self.ln(x) # BS x SL x 384 (Embed Size)
        logits = self.final_linear(x) # BS x SL x 4096 (vocab size)



        if targets is not None:
            BS, SL, VS = logits.shape # BS x SL x 4906 (Vocabulary Size)
            logits = logits.view(BS*SL, VS)
            targets = targets.view(BS*SL)
            loss = F.cross_entropy(logits, targets)     


            # Manual calculation 
            counts = logits.exp()
            prob = counts / counts.sum(-1, keepdim = True) # Keep dim = keeping the dimension for dividing each single dimension
            loss2 = prob[torch.arange(BS*SL), targets].log().mean()
            # E.g., Target[3] = 329 prob[3][329] = 0.014
            # Cross entropy = - Log p(x)

            # if (not torch.allclose(loss, loss2)): # This is to show Pytorch calculate entropy is a bit different from manual way, on a time-to-time basis
            #    print(f"[Loss Diff] Pytorch:{loss.item()} Manual:{loss2.item()}")
                
        return logits, loss

        # Generate a new sample
    def generate(self, input, max = 500):
        for _ in range(max):
            input = input[:, -context:] # (1, input length until max of SL)
            logits, _ = self(input) # (1, input length, 4096)
            logits = logits[:, -1,:] # Pick last logits/probability (1, 4096) as we are extracting the last token
            probs = F.softmax(logits, dim = -1) # (1, 4096)
            next = torch.multinomial(probs, num_samples = 1)
            input = torch.cat((input, next), dim = 1)
        return input

# %%
class Block(nn.Module):
    def __init__(self, n_heads):
        super().__init__()
        head_size = embed_size // n_heads
        self.ma = Multihead(n_heads, head_size)
        self.feed_forward = ForwardLayer(embed_size)
        self.ln1 = nn.LayerNorm(embed_size)
        self.ln2 = nn.LayerNorm(embed_size)


    def forward(self, x):
        x = x + self.ma(self.ln1(x))
        x = x + self.feed_forward(self.ln2(x))
        return x

# %%
class ForwardLayer(nn.Module):
    def __init__(self, embed_size):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(embed_size, 6 * embed_size, bias = BIAS),
        nn.GELU(),
        nn.Linear(6 * embed_size, embed_size, bias = BIAS),
        nn.Dropout(dropout)
    )

    def forward(self, x):
        x = self.network(x)
        return x

# %%
class Multihead(nn.Module):
    def __init__(self, n_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(n_heads)])
        self.combine = nn.Linear(head_size * n_heads, embed_size, bias = BIAS) # 378, 384
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = torch.cat([head(x) for head in self.heads], dim = -1)
        # Each head output (BS, SL, head_size)
        x = self.combine(x)
        x = self.dropout(x)
        return x

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.queries = nn.Linear(embed_size, head_size, bias = BIAS)
        self.keys = nn.Linear(embed_size, head_size, bias = BIAS)
        self.values = nn.Linear(embed_size, head_size, bias = BIAS)

        self.register_buffer('tril', torch.tril(torch.ones(context, context)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        BS, SL, VS = x.shape
        q = self.queries(x) # BS, SL, 54
        k = self.keys(x) # BS, SL, 54
        v = self.values(x) # BS, SL, 54

        attn_w = q @ k.transpose(-2, -1) * k.shape[-1]**-0.5 # BS, SL, SL
        attn_w = attn_w.masked_fill(self.tril[:SL, :SL] == 0, float('-inf'))
        attn_w = F.softmax(attn_w, dim = -1) # BS, SL, SL

        x = attn_w @ v # BS, SL, 54

        return x

# %%
head_size = embed_size // n_heads
print(f"embed: {embed_size} n_heads: {n_heads} head_size: {head_size}")
# Out:
# embed: 384 n_heads: 7 head_size: 54

# %%
# Understand the attention calculations
# Commented out as it is for learning purpose 

'''
x, y = get_batch('train')
print(x.shape, y.shape)
print(x[0][:10])
print(y[0][:10])
x = x.to(device)
y = y.to(device)

embeddings = nn.Embedding(vocab_size, embed_size).to(device)
positions = nn.Embedding(context, embed_size).to(device)
queries = nn.Linear(embed_size, head_size, bias = BIAS).to(device)
keys = nn.Linear(embed_size, head_size, bias = BIAS).to(device)
values = nn.Linear(embed_size, head_size, bias = BIAS).to(device)
tril = torch.tril(torch.ones(context, context)).to(device)

emb = embeddings(x)
pos = positions(torch.arange(context, device = device))
x = emb + pos

q = queries(x)
k = keys(x)
v = values(x)
print(q.shape, k.shape, v.shape)
torch.set_printoptions(precision = 2, sci_mode = False)
print(q[0][0][:5])

attn_w = q @ k.transpose(-2, -1) * k.shape[-1] ** -0.5
attn_w = attn_w.masked_fill(tril[:context, :context] == 0, float('-inf'))
attn_w = F.softmax(attn_w, dim = -1)
x = attn_w @ v
'''
# Out:
# "\nx, y = get_batch('train')\nprint(x.shape, y.shape)\nprint(x[0][:10])\nprint(y[0][:10])\nx = x.to(device)\ny = y.to(device)\n\nembeddings = nn.Embedding(vocab_size, embed_size).to(device)\npositions = nn.Embedding(context, embed_size).to(device)\nqueries = nn.Linear(embed_size, head_size, bias = BIAS).to(device)\nkeys = nn.Linear(embed_size, head_size, bias = BIAS).to(device)\nvalues = nn.Linear(embed_size, head_size, bias = BIAS).to(device)\ntril = torch.tril(torch.ones(context, context)).to(device)\n\nemb = embeddings(x)\npos = positions(torch.arange(context, device = device))\nx = emb + pos\n\nq = queries(x)\nk = keys(x)\nv = values(x)\nprint(q.shape, k.shape, v.shape)\ntorch.set_printoptions(precision = 2, sci_mode = False)\nprint(q[0][0][:5])\n\nattn_w = q @ k.transpose(-2, -1) * k.shape[-1] ** -0.5\nattn_w = attn_w.masked_fill(tril[:context, :context] == 0, float('-inf'))\nattn_w = F.softmax(attn_w, dim = -1)\nx = attn_w @ v\n"

# %%
# Understand Attention Matrix
# Commented out as it is for learning purpose 
'''
full = q @ k.transpose(-2, -1) # 512*54 @ 54 x 512 = 512 x 512

a = q[0][5]
b = k.transpose(-2, -1)[0, :, 3]
print(a, b)
c = torch.dot(a, b)
print(c)
print(full[0][5][3])
'''
# Out:
# '\nfull = q @ k.transpose(-2, -1) # 512*54 @ 54 x 512 = 512 x 512\n\na = q[0][5]\nb = k.transpose(-2, -1)[0, :, 3]\nprint(a, b)\nc = torch.dot(a, b)\nprint(c)\nprint(full[0][5][3])\n'

# %%
# Understand the updating of the V content
# Commented out as it is for learning purpose 
'''
print(attn_w.shape, v.shape)

print(x[0][7])

attn_scores2 = attn_w[0, 7, :] # Shape [512]

# Initialize a tensor to sotre the result
result = torch.zeros(54)
# Compute the dot product for each column in V for the first tokens in the first batch
for i in range(54):
    result[i] = torch.dot(attn_scores2, v[0, :, i])

print(result)
'''
# Out:
# '\nprint(attn_w.shape, v.shape)\n\nprint(x[0][7])\n\nattn_scores2 = attn_w[0, 7, :] # Shape [512]\n\n# Initialize a tensor to sotre the result\nresult = torch.zeros(54)\n# Compute the dot product for each column in V for the first tokens in the first batch\nfor i in range(54):\n    result[i] = torch.dot(attn_scores2, v[0, :, i])\n\nprint(result)\n'

# %%
# Optional (after doing it, take out the loss2 from the output of the model)
x, y = get_batch('train')
print(x.shape, y.shape)
print(x[0][:10])
print(y[0][:10])

model = GPT()
model = model.to(dtype) # Denote the precision level
model = model.to(device)


# logit, loss, loss2 = model(x, y)
# print(loss.item(), loss2.item())
# Out:
# torch.Size([32, 512]) torch.Size([32, 512])
# tensor([4055,  307,  590,  337,  430, 1248, 4042, 2087,  437, 1675],
#        device='cuda:0')
# tensor([ 307,  590,  337,  430, 1248, 4042, 2087,  437, 1675,  441],
#        device='cuda:0')

# %%
@torch.no_grad()
def generate_sample(input):
    t1 = torch.tensor(encode(input), dtype = torch.long, device = device) # take input, encode it, transform to tensor
    t1 = t1[None, :] # (1, [size of the ids]  - BS = 1 as we are inferencing
    newgen = model.generate(t1, max = 64)[0].tolist()
    result = decode(newgen)
    print(f"{result}")

# generate_sample('I am a person.')

# %%
# Training Setup


model = GPT()
model = model.to(dtype)
model = model.to(device)

if compile:
    print('Torch: Compiling model')
    model = torch.compile (model)

print(sum(p.numel() for p in model.parameters()) / 1e6, 'Million parameters')
# Out:
# Torch: Compiling model
# 19.837954 Million parameters

# %%
# Calculate loss averages
import torch._dynamo
torch._dynamo.config.suppress_errors = True

@torch.no_grad()
def calculate_loss():
# WE are evaluating but not training so this decorator
    out = {}
    model.eval()
    for split in ['train', 'eval']:
        l = torch.zeros(eval_iters)
        # calculation the MEAN of the loss
        for i in range(eval_iters):
            x, y = get_batch(split)
            _, loss = model(x, y)
            l[i] = loss
        out[split] = l.mean().item()
    model.train()
    return out

l = calculate_loss()
print(l)
# Out:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward C:\Users\ZGMF-X42S\AppData\Local\Temp\ipykernel_2036\3703986496.py line 23
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1029 11:03:09.496000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward C:\Users\ZGMF-X42S\AppData\Local\Temp\ipykernel_2036\1309120871.py line 11
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1029 11:03:11.380000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# ...
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\ZGMF-X42S\miniconda3\envs\test2\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1029 11:03:13.373000 2036 site-packages\torch\_dynamo\convert_frame.py:1125]
# {'train': 8.375, 'eval': 8.375}

# %%
# Optimizer for minimizing the cross-entropy loss 

p_dict = {p_name: p for p_name, p in model.named_parameters() if p.requires_grad}

# Only those with multiple dimensions will benefit from the weight decay
weight_decay_p = [p for n, p in p_dict.items() if p.dim() >= 2]

no_weight_decay_p = [p for n, p in p_dict.items() if p.dim() <2]


optimizer_groups = [
    {'params': weight_decay_p, 'weight_decay': weight_decay},
    {'params': no_weight_decay_p, 'weight_decay': 0.0}
]

optimizer = torch.optim.AdamW(optimizer_groups, lr = lr, betas = (0.9, 0.99))

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, train_iters, eta_min = lr / 10) 

start_iteration = 0
best_val_loss = float('inf') # Track the best validation loss value

# %%
# Loading Checkpoints


# def load_checkpoint(path):
#     print('LLM - Loading Model')
#     checkpoint = torch.load(path)
#     model.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     iteration = checkpoint['iteration']
#     loss = checkpoint['loss']
#     print(f"Loaded iter {iteration} with loss {loss}")
#     return iteration, loss


# if os.path.exists(f"{checkpoint_dir}/{checkpoint_fn}") and load_pretrained:
#     checkpoint_path = f"{checkpoint_dir}/{checkpoint_load_fn}"
#     start_iteration, loss = load_checkpoint(checkpoint_path)
#     best_val_loss = loss


def load_checkpoint(path):
    print('LLM - Loading Model')
    try:
        checkpoint = torch.load(path)
        print("\nCheckpoint contents:")
        for key in checkpoint.keys():
            print(f"- {key}")
            
        if 'model_state_dict' in checkpoint:
            checkpoint_state = checkpoint['model_state_dict']
            
            # Try to handle OptimizedModule wrapper
            if hasattr(model, '_orig_mod'):
                print("Detected OptimizedModule wrapper, attempting to load into _orig_mod")
                try:
                    # Try loading into the wrapped module
                    model._orig_mod.load_state_dict(checkpoint_state)
                    print("Successfully loaded state into _orig_mod")
                except Exception as e:
                    print(f"Failed to load into _orig_mod: {str(e)}")
                    # If that fails, try to modify the state dict keys
                    modified_state = {"_orig_mod." + k: v for k, v in checkpoint_state.items()}
                    try:
                        model.load_state_dict(modified_state)
                        print("Successfully loaded state with modified keys")
                    except Exception as e2:
                        print(f"Failed to load with modified keys: {str(e2)}")
                        raise
            else:
                # Regular loading if no wrapper
                model.load_state_dict(checkpoint_state)
                
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        iteration = checkpoint['iteration']
        loss = checkpoint['loss']
        print(f"Loaded iter {iteration} with loss {loss}")
        return iteration, loss
        
    except Exception as e:
        print(f"\nDetailed error information:")
        print(f"Error type: {type(e).__name__}")
        print(f"Error message: {str(e)}")
        
        # Print some debugging information
        if 'model_state_dict' in checkpoint:
            print("\nFirst few checkpoint keys:")
            for k in list(checkpoint['model_state_dict'].keys())[:5]:
                print(f"- {k}")
            
            print("\nFirst few model state_dict keys:")
            for k in list(model.state_dict().keys())[:5]:
                print(f"- {k}")
        raise

if os.path.exists(f"{checkpoint_dir}/{checkpoint_load_fn}") and load_pretrained:
    checkpoint_path = f"{checkpoint_dir}/{checkpoint_load_fn}"
    print(f"Loading checkpoint from: {checkpoint_path}")
    start_iteration, loss = load_checkpoint(checkpoint_path)
    best_val_loss = loss

# DEBUGGING MODULE
# def load_checkpoint(path):
#     print('LLM - Loading Model')
#     try:
#         # Check if path exists
#         if not os.path.exists(path):
#             print(f"Checkpoint path not found: {path}")
#             return 0, float('inf')
            
#         checkpoint = torch.load(path)
#         model.load_state_dict(checkpoint['model_state_dict'])
#         optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#         iteration = checkpoint['iteration']
#         loss = checkpoint['loss']
#         print(f"Loaded iter {iteration} with loss {loss}")
#         return iteration, loss
#     except Exception as e:
#         print(f"Error loading checkpoint: {e}")
#         return 0, float('inf')

# # Fix path construction
# checkpoint_path = os.path.join(checkpoint_dir, checkpoint_fn)
# # or
# # checkpoint_path = f"{checkpoint_dir}/{checkpoint_fn}"

# print(f"Checking path: {checkpoint_path}")
# print(f"Path exists: {os.path.exists(checkpoint_path)}")
# print(f"load_pretrained value: {load_pretrained}")

# if os.path.exists(checkpoint_path) and load_pretrained:
#     print("Loading checkpoint...")
#     start_iteration, loss = load_checkpoint(checkpoint_path)
#     best_val_loss = loss
# else:
#     print("No checkpoint loaded because:")
#     if not os.path.exists(checkpoint_path):
#         print(f"- Checkpoint path does not exist: {checkpoint_path}")
#     if not load_pretrained:
#         print("- load_pretrained is False")
# Out:
# Loading checkpoint from: models//latest.pt
# LLM - Loading Model
# C:\Users\ZGMF-X42S\AppData\Local\Temp\ipykernel_2036\3390700552.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path)
# Checkpoint contents:
# - model_state_dict
# - optimizer_state_dict
# - loss
# - iteration
# Detected OptimizedModule wrapper, attempting to load into _orig_mod
# Failed to load into _orig_mod: Error(s) in loading state_dict for GPT:
# 	Missing key(s) in state_dict: "embeddings.weight", "positions.weight", "blocks.0.ma.heads.0.tril", "blocks.0.ma.heads.0.queries.weight", "blocks.0.ma.heads.0.queries.bias", "blocks.0.ma.heads.0.keys.weight", "blocks.0.ma.heads.0.keys.bias", "blocks.0.ma.heads.0.values.weight", "blocks.0.ma.heads.0.values.bias", "blocks.0.ma.heads.1.tril", "blocks.0.ma.heads.1.queries.weight", "blocks.0.ma.heads.1.queries.bias", "blocks.0.ma.heads.1.keys.weight", "blocks.0.ma.heads.1.keys.bias", "blocks.0.ma.heads.1.values.weight", "blocks.0.ma.heads.1.values.bias", "blocks.0.ma.heads.2.tril", "blocks.0.ma.heads.2.queries.weight", "blocks.0.ma.heads.2.queries.bias", "blocks.0.ma.heads.2.keys.weight", "blocks.0.ma.heads.2.keys.bias", "blocks.0.ma.heads.2.values.weight", "blocks.0.ma.heads.2.values.bias", "blocks.0.ma.heads.3.tril", "blocks.0.ma.heads.3.queries.weight", "blocks.0.ma.heads.3.queries.bias", "blocks.0.ma.heads.3.keys.weight", "blocks.0.ma.heads.3.keys.bias", "blocks.0.ma.heads.3.values.weight", "blocks.0.ma.heads.3.values.bias", "blocks.0.ma.heads.4.tril", "blocks.0.ma.heads.4.queries.weight", "blocks.0.ma.heads.4.queries.bias", "blocks.0.ma.heads.4.keys.weight", "blocks.0.ma.heads.4.keys.bias", "blocks.0.ma.heads.4.values.weight", "blocks.0.ma.heads.4.values.bias", "blocks.0.ma.heads.5.tril", "blocks.0.ma.heads.5.queries.weight", "blocks.0.ma.heads.5.queries.bias", "blocks.0.ma.heads.5.keys.weight", "blocks.0.ma.heads.5.keys.bias", "blocks.0.ma.heads.5.values.weight", "blocks.0.ma.heads.5.values.bias", "blocks.0.ma.heads.6.tril", "blocks.0.ma.heads.6.queries.weight", "blocks.0.ma.heads.6.queries.bias", "blocks.0.ma.heads.6.keys.weight", "blocks.0.ma.heads.6.keys.bias", "blocks.0.ma.heads.6.values.weight", "blocks.0.ma.heads.6.values.bias", "blocks.0.ma.combine.weight", "blocks.0.ma.combine.bias", "blocks.0.feed_forward.network.0.weight", "blocks.0.feed_forward.network.0.bias", "blocks.0.feed_forward.network.2.weight", "blocks.0.feed_forward.network.2.bias", "blocks.0.ln1.weight", "blocks.0.ln1.bias", "blocks.0.ln2.weight", "blocks.0.ln2.bias", "blocks.1.ma.heads.0.tril", "blocks.1.ma.heads.0.queries.weight", "blocks.1.ma.heads.0.queries.bias", "blocks.1.ma.heads.0.keys.weight", "blocks.1.ma.heads.0.keys.bias", "blocks.1.ma.heads.0.values.weight", "blocks.1.ma.heads.0.values.bias", "blocks.1.ma.heads.1.tril", "blocks.1.ma.heads.1.queries.weight", "blocks.1.ma.heads.1.queries.bias", "blocks.1.ma.heads.1.keys.weight", "blocks.1.ma.heads.1.keys.bias", "blocks.1.ma.heads.1.values.weight", "blocks.1.ma.heads.1.values.bias", "blocks.1.ma.heads.2.tril", "blocks.1.ma.heads.2.queries.weight", "blocks.1.ma.heads.2.queries.bias", "blocks.1.ma.heads.2.keys.weight", "blocks.1.ma.heads.2.keys.bias", "blocks.1.ma.heads.2.values.weight", "blocks.1.ma.heads.2.values.bias", "blocks.1.ma.heads.3.tril", "blocks.1.ma.heads.3.queries.weight", "blocks.1.ma.heads.3.queries.bias", "blocks.1.ma.heads.3.keys.weight", "blocks.1.ma.heads.3.keys.bias", "blocks.1.ma.heads.3.values.weight", "blocks.1.ma.heads.3.values.bias", "blocks.1.ma.heads.4.tril", "blocks.1.ma.heads.4.queries.weight", "blocks.1.ma.heads.4.queries.bias", "blocks.1.ma.heads.4.keys.weight", "blocks.1.ma.heads.4.keys.bias", "blocks.1.ma.heads.4.values.weight", "blocks.1.ma.heads.4.values.bias", "blocks.1.ma.heads.5.tril", "blocks.1.ma.heads.5.queries.weight", "blocks.1.ma.heads.5.queries.bias", "blocks.1.ma.heads.5.keys.weight", "blocks.1.ma.heads.5.keys.bias", "blocks.1.ma.heads.5.values.weight", "blocks.1.ma.heads.5.values.bias", "blocks.1.ma.heads.6.tril", "blocks.1.ma.heads.6.queries.weight", "blocks.1.ma.heads.6.queries.bias", "blocks.1.ma.heads.6.keys.weight", "blocks.1.ma.heads.6.keys.bias", "blocks.1.ma.heads.6.values.weight", "blocks.1.ma.heads.6.values.bias", "blocks.1.ma.combine.weight", "blocks.1.ma.combine.bias", "blocks.1.feed_forward.network.0.weight", "blocks.1.feed_forward.network.0.bias", "blocks.1.feed_forward.network.2.weight", "blocks.1.feed_forward.network.2.bias", "blocks. ...
# 	Unexpected key(s) in state_dict: "_orig_mod.embeddings.weight", "_orig_mod.positions.weight", "_orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod.blocks.0.ma.combine.weight", "_orig_mod.blocks.0.ma.combine.bias", "_orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod.blocks.0.ln1.weight", "_orig_mod.blocks.0.ln1.bias", "_orig_mod.blocks.0.ln2.weight", "_orig_mod.blocks.0.ln2.bias", "_orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod.blocks.1.ma.heads.1.values.weight", "_orig_mod.blocks.1.ma.heads.1.values.bias", "_orig_mod.blocks.1.ma.heads.2.tril", "_orig_mod.blocks.1.ma.heads.2.queries.weight", "_orig_mod.blocks.1.ma.heads.2.queries.bias", "_orig_mod.blocks.1.ma.heads.2.keys.weight", "_orig_mod.blocks.1.ma.heads.2.keys.bias", "_orig_mod.blocks.1.ma.heads.2.values.weight", "_orig_mod.blocks.1.ma.heads.2.values.bias", "_orig_mod.blocks.1.ma.heads.3.tril", "_orig_mod.blocks.1.ma.heads.3.queries.weight", "_orig_mod.blocks.1.ma.heads.3.queries.bias", "_orig_mod.blocks.1.ma.heads.3.keys.weight", "_orig_mod.blocks.1.ma.heads.3.keys.bias", "_orig_mod.blocks.1.ma.heads.3.values.weight", "_orig_mod.blocks.1.ma.heads.3.values.bias", "_orig_mod.blocks.1.ma.heads.4.tril", "_orig_mod.blocks.1.ma.he ...
# Failed to load with modified keys: Error(s) in loading state_dict for OptimizedModule:
# 	Missing key(s) in state_dict: "_orig_mod.embeddings.weight", "_orig_mod.positions.weight", "_orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod.blocks.0.ma.combine.weight", "_orig_mod.blocks.0.ma.combine.bias", "_orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod.blocks.0.ln1.weight", "_orig_mod.blocks.0.ln1.bias", "_orig_mod.blocks.0.ln2.weight", "_orig_mod.blocks.0.ln2.bias", "_orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod.blocks.1.ma.heads.1.values.weight", "_orig_mod.blocks.1.ma.heads.1.values.bias", "_orig_mod.blocks.1.ma.heads.2.tril", "_orig_mod.blocks.1.ma.heads.2.queries.weight", "_orig_mod.blocks.1.ma.heads.2.queries.bias", "_orig_mod.blocks.1.ma.heads.2.keys.weight", "_orig_mod.blocks.1.ma.heads.2.keys.bias", "_orig_mod.blocks.1.ma.heads.2.values.weight", "_orig_mod.blocks.1.ma.heads.2.values.bias", "_orig_mod.blocks.1.ma.heads.3.tril", "_orig_mod.blocks.1.ma.heads.3.queries.weight", "_orig_mod.blocks.1.ma.heads.3.queries.bias", "_orig_mod.blocks.1.ma.heads.3.keys.weight", "_orig_mod.blocks.1.ma.heads.3.keys.bias", "_orig_mod.blocks.1.ma.heads.3.values.weight", "_orig_mod.blocks.1.ma.heads.3.values.bias", "_orig_mod.blocks.1.ma.heads.4.tril", "_orig_mod.blocks.1.ma.heads ...
# 	Unexpected key(s) in state_dict: "_orig_mod._orig_mod.embeddings.weight", "_orig_mod._orig_mod.positions.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod._orig_mod.blocks.0.ma.combine.weight", "_orig_mod._orig_mod.blocks.0.ma.combine.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod._orig_mod.blocks.0.ln1.weight", "_orig_mod._orig_mod.blocks.0.ln1.bias", "_orig_mod._orig_mod.blocks.0.ln2.weight", "_orig_mod._orig_mod.blocks.0.ln2.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.values.w ...
#
# Detailed error information:
# Error type: RuntimeError
# Error message: Error(s) in loading state_dict for OptimizedModule:
# 	Missing key(s) in state_dict: "_orig_mod.embeddings.weight", "_orig_mod.positions.weight", "_orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod.blocks.0.ma.combine.weight", "_orig_mod.blocks.0.ma.combine.bias", "_orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod.blocks.0.ln1.weight", "_orig_mod.blocks.0.ln1.bias", "_orig_mod.blocks.0.ln2.weight", "_orig_mod.blocks.0.ln2.bias", "_orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod.blocks.1.ma.heads.1.values.weight", "_orig_mod.blocks.1.ma.heads.1.values.bias", "_orig_mod.blocks.1.ma.heads.2.tril", "_orig_mod.blocks.1.ma.heads.2.queries.weight", "_orig_mod.blocks.1.ma.heads.2.queries.bias", "_orig_mod.blocks.1.ma.heads.2.keys.weight", "_orig_mod.blocks.1.ma.heads.2.keys.bias", "_orig_mod.blocks.1.ma.heads.2.values.weight", "_orig_mod.blocks.1.ma.heads.2.values.bias", "_orig_mod.blocks.1.ma.heads.3.tril", "_orig_mod.blocks.1.ma.heads.3.queries.weight", "_orig_mod.blocks.1.ma.heads.3.queries.bias", "_orig_mod.blocks.1.ma.heads.3.keys.weight", "_orig_mod.blocks.1.ma.heads.3.keys.bias", "_orig_mod.blocks.1.ma.heads.3.values.weight", "_orig_mod.blocks.1.ma.heads.3.values.bias", "_orig_mod.blocks.1.ma.heads.4.tril", "_orig_mod.blocks.1.ma.heads ...
# 	Unexpected key(s) in state_dict: "_orig_mod._orig_mod.embeddings.weight", "_orig_mod._orig_mod.positions.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod._orig_mod.blocks.0.ma.combine.weight", "_orig_mod._orig_mod.blocks.0.ma.combine.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod._orig_mod.blocks.0.ln1.weight", "_orig_mod._orig_mod.blocks.0.ln1.bias", "_orig_mod._orig_mod.blocks.0.ln2.weight", "_orig_mod._orig_mod.blocks.0.ln2.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.values.w ...
#
# First few checkpoint keys:
# - _orig_mod.embeddings.weight
# - _orig_mod.positions.weight
# - _orig_mod.blocks.0.ma.heads.0.tril
# - _orig_mod.blocks.0.ma.heads.0.queries.weight
# - _orig_mod.blocks.0.ma.heads.0.queries.bias
#
# First few model state_dict keys:
# - _orig_mod.embeddings.weight
# - _orig_mod.positions.weight
# - _orig_mod.blocks.0.ma.heads.0.tril
# - _orig_mod.blocks.0.ma.heads.0.queries.weight
# - _orig_mod.blocks.0.ma.heads.0.queries.bias
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 37, in load_checkpoint(path)
#      35 try:
#      36     # Try loading into the wrapped module
# ---> 37     model._orig_mod.load_state_dict(checkpoint_state)
#      38     print("Successfully loaded state into _orig_mod")
#
# File ~\miniconda3\envs\test2\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for GPT:
# 	Missing key(s) in state_dict: "embeddings.weight", "positions.weight", "blocks.0.ma.heads.0.tril", "blocks.0.ma.heads.0.queries.weight", "blocks.0.ma.heads.0.queries.bias", "blocks.0.ma.heads.0.keys.weight", "blocks.0.ma.heads.0.keys.bias", "blocks.0.ma.heads.0.values.weight", "blocks.0.ma.heads.0.values.bias", "blocks.0.ma.heads.1.tril", "blocks.0.ma.heads.1.queries.weight", "blocks.0.ma.heads.1.queries.bias", "blocks.0.ma.heads.1.keys.weight", "blocks.0.ma.heads.1.keys.bias", "blocks.0.ma.heads.1.values.weight", "blocks.0.ma.heads.1.values.bias", "blocks.0.ma.heads.2.tril", "blocks.0.ma.heads.2.queries.weight", "blocks.0.ma.heads.2.queries.bias", "blocks.0.ma.heads.2.keys.weight", "blocks.0.ma.heads.2.keys.bias", "blocks.0.ma.heads.2.values.weight", "blocks.0.ma.heads.2.values.bias", "blocks.0.ma.heads.3.tril", "blocks.0.ma.heads.3.queries.weight", "blocks.0.ma.heads.3.queries.bias", "blocks.0.ma.heads.3.keys.weight", "blocks.0.ma.heads.3.keys.bias", "blocks.0.ma.heads.3.values.weight", "blocks.0.ma.heads.3.values.bias", "blocks.0.ma.heads.4.tril", "blocks.0.ma.heads.4.queries.weight", "blocks.0.ma.heads.4.queries.bias", "blocks.0.ma.heads.4.keys.weight", "blocks.0.ma.heads.4.keys.bias", "blocks.0.ma.heads.4.values.weight", "blocks.0.ma.heads.4.values.bias", "blocks.0.ma.heads.5.tril", "blocks.0.ma.heads.5.queries.weight", "blocks.0.ma.heads.5.queries.bias", "blocks.0.ma.heads.5.keys.weight", "blocks.0.ma.heads.5.keys.bias", "blocks.0.ma.heads.5.values.weight", "blocks.0.ma.heads.5.values.bias", "blocks.0.ma.heads.6.tril", "blocks.0.ma.heads.6.queries.weight", "blocks.0.ma.heads.6.queries.bias", "blocks.0.ma.heads.6.keys.weight", "blocks.0.ma.heads.6.keys.bias", "blocks.0.ma.heads.6.values.weight", "blocks.0.ma.heads.6.values.bias", "blocks.0.ma.combine.weight", "blocks.0.ma.combine.bias", "blocks.0.feed_forward.network.0.weight", "blocks.0.feed_forward.network.0.bias", "blocks.0.feed_forward.network.2.weight", "blocks.0.feed_forward.network.2.bias", "blocks.0.ln1.weight", "blocks.0.ln1.bias", "blocks.0.ln2.weight", "blocks.0.ln2.bias", "blocks.1.ma.heads.0.tril", "blocks.1.ma.heads.0.queries.weight", "blocks.1.ma.heads.0.queries.bias", "blocks.1.ma.heads.0.keys.weight", "blocks.1.ma.heads.0.keys.bias", "blocks.1.ma.heads.0.values.weight", "blocks.1.ma.heads.0.values.bias", "blocks.1.ma.heads.1.tril", "blocks.1.ma.heads.1.queries.weight", "blocks.1.ma.heads.1.queries.bias", "blocks.1.ma.heads.1.keys.weight", "blocks.1.ma.heads.1.keys.bias", "blocks.1.ma.heads.1.values.weight", "blocks.1.ma.heads.1.values.bias", "blocks.1.ma.heads.2.tril", "blocks.1.ma.heads.2.queries.weight", "blocks.1.ma.heads.2.queries.bias", "blocks.1.ma.heads.2.keys.weight", "blocks.1.ma.heads.2.keys.bias", "blocks.1.ma.heads.2.values.weight", "blocks.1.ma.heads.2.values.bias", "blocks.1.ma.heads.3.tril", "blocks.1.ma.heads.3.queries.weight", "blocks.1.ma.heads.3.queries.bias", "blocks.1.ma.heads.3.keys.weight", "blocks.1.ma.heads.3.keys.bias", "blocks.1.ma.heads.3.values.weight", "blocks.1.ma.heads.3.values.bias", "blocks.1.ma.heads.4.tril", "blocks.1.ma.heads.4.queries.weight", "blocks.1.ma.heads.4.queries.bias", "blocks.1.ma.heads.4.keys.weight", "blocks.1.ma.heads.4.keys.bias", "blocks.1.ma.heads.4.values.weight", "blocks.1.ma.heads.4.values.bias", "blocks.1.ma.heads.5.tril", "blocks.1.ma.heads.5.queries.weight", "blocks.1.ma.heads.5.queries.bias", "blocks.1.ma.heads.5.keys.weight", "blocks.1.ma.heads.5.keys.bias", "blocks.1.ma.heads.5.values.weight", "blocks.1.ma.heads.5.values.bias", "blocks.1.ma.heads.6.tril", "blocks.1.ma.heads.6.queries.weight", "blocks.1.ma.heads.6.queries.bias", "blocks.1.ma.heads.6.keys.weight", "blocks.1.ma.heads.6.keys.bias", "blocks.1.ma.heads.6.values.weight", "blocks.1.ma.heads.6.values.bias", "blocks.1.ma.combine.weight", "blocks.1.ma.combine.bias", "blocks.1.feed_forward.network.0.weight", "blocks.1.feed_forward.network.0.bias", "blocks.1.feed_forward.network.2.weight", "blocks.1.feed_forward.network.2.bias", "blocks. ...
# 	Unexpected key(s) in state_dict: "_orig_mod.embeddings.weight", "_orig_mod.positions.weight", "_orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod.blocks.0.ma.combine.weight", "_orig_mod.blocks.0.ma.combine.bias", "_orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod.blocks.0.ln1.weight", "_orig_mod.blocks.0.ln1.bias", "_orig_mod.blocks.0.ln2.weight", "_orig_mod.blocks.0.ln2.bias", "_orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod.blocks.1.ma.heads.1.values.weight", "_orig_mod.blocks.1.ma.heads.1.values.bias", "_orig_mod.blocks.1.ma.heads.2.tril", "_orig_mod.blocks.1.ma.heads.2.queries.weight", "_orig_mod.blocks.1.ma.heads.2.queries.bias", "_orig_mod.blocks.1.ma.heads.2.keys.weight", "_orig_mod.blocks.1.ma.heads.2.keys.bias", "_orig_mod.blocks.1.ma.heads.2.values.weight", "_orig_mod.blocks.1.ma.heads.2.values.bias", "_orig_mod.blocks.1.ma.heads.3.tril", "_orig_mod.blocks.1.ma.heads.3.queries.weight", "_orig_mod.blocks.1.ma.heads.3.queries.bias", "_orig_mod.blocks.1.ma.heads.3.keys.weight", "_orig_mod.blocks.1.ma.heads.3.keys.bias", "_orig_mod.blocks.1.ma.heads.3.values.weight", "_orig_mod.blocks.1.ma.heads.3.values.bias", "_orig_mod.blocks.1.ma.heads.4.tril", "_orig_mod.blocks.1.ma.he ...
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 78
#      76     checkpoint_path = f"{checkpoint_dir}/{checkpoint_load_fn}"
#      77     print(f"Loading checkpoint from: {checkpoint_path}")
# ---> 78     start_iteration, loss = load_checkpoint(checkpoint_path)
#      79     best_val_loss = loss
#      81 # DEBUGGING MODULE
#      82 # def load_checkpoint(path):
#      83 #     print('LLM - Loading Model')
#    (...)
#     118 #     if not load_pretrained:
#     119 #         print("- load_pretrained is False")
#
# Cell In[23], line 44, in load_checkpoint(path)
#      42 modified_state = {"_orig_mod." + k: v for k, v in checkpoint_state.items()}
#      43 try:
# ---> 44     model.load_state_dict(modified_state)
#      45     print("Successfully loaded state with modified keys")
#      46 except Exception as e2:
#
# File ~\miniconda3\envs\test2\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for OptimizedModule:
# 	Missing key(s) in state_dict: "_orig_mod.embeddings.weight", "_orig_mod.positions.weight", "_orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod.blocks.0.ma.combine.weight", "_orig_mod.blocks.0.ma.combine.bias", "_orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod.blocks.0.ln1.weight", "_orig_mod.blocks.0.ln1.bias", "_orig_mod.blocks.0.ln2.weight", "_orig_mod.blocks.0.ln2.bias", "_orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod.blocks.1.ma.heads.1.values.weight", "_orig_mod.blocks.1.ma.heads.1.values.bias", "_orig_mod.blocks.1.ma.heads.2.tril", "_orig_mod.blocks.1.ma.heads.2.queries.weight", "_orig_mod.blocks.1.ma.heads.2.queries.bias", "_orig_mod.blocks.1.ma.heads.2.keys.weight", "_orig_mod.blocks.1.ma.heads.2.keys.bias", "_orig_mod.blocks.1.ma.heads.2.values.weight", "_orig_mod.blocks.1.ma.heads.2.values.bias", "_orig_mod.blocks.1.ma.heads.3.tril", "_orig_mod.blocks.1.ma.heads.3.queries.weight", "_orig_mod.blocks.1.ma.heads.3.queries.bias", "_orig_mod.blocks.1.ma.heads.3.keys.weight", "_orig_mod.blocks.1.ma.heads.3.keys.bias", "_orig_mod.blocks.1.ma.heads.3.values.weight", "_orig_mod.blocks.1.ma.heads.3.values.bias", "_orig_mod.blocks.1.ma.heads.4.tril", "_orig_mod.blocks.1.ma.heads ...
# 	Unexpected key(s) in state_dict: "_orig_mod._orig_mod.embeddings.weight", "_orig_mod._orig_mod.positions.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.1.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.2.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.3.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.4.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.5.values.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.tril", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.queries.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.keys.bias", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.weight", "_orig_mod._orig_mod.blocks.0.ma.heads.6.values.bias", "_orig_mod._orig_mod.blocks.0.ma.combine.weight", "_orig_mod._orig_mod.blocks.0.ma.combine.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.0.bias", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.weight", "_orig_mod._orig_mod.blocks.0.feed_forward.network.2.bias", "_orig_mod._orig_mod.blocks.0.ln1.weight", "_orig_mod._orig_mod.blocks.0.ln1.bias", "_orig_mod._orig_mod.blocks.0.ln2.weight", "_orig_mod._orig_mod.blocks.0.ln2.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.0.values.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.tril", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.queries.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.weight", "_orig_mod._orig_mod.blocks.1.ma.heads.1.keys.bias", "_orig_mod._orig_mod.blocks.1.ma.heads.1.values.w ...

# %%
# Inference 

if inference == True: 
    model.eval()
    while True:
        qs = input('Enter text (q to quit): ')
        if qs == "":
            continue
        if qs == "q":
            break
        generate_sample(qs)
# Out:
# Enter text (q to quit):  I go to school by bus
# I go to school by bus books colon~ waysexev Chic joined chart estungient market Danielcience Jes UKiol enginealf Khem suggestyr Hel clos being Wal agre phrey Hist Blackended Bang tooilesston Persight sing Walpleming Khatithingimbround heldylesp near Angelesired medicalanks politician Japangest Os COVID building computer
# Enter text (q to quit):  q

# %%
# Training Loop

try:
    for i in tqdm(range(start_iteration, train_iters)):
        print(f"Iteration: {i}")
        xb, yb = get_batch('train')
        logits, loss = model(xb, yb)
    
        # Evaluating loss
        if (i % eval_interval == 0 or i == train_iters-1):
            l = calculate_loss()
            print(f"\n{i}: train loss: {l['train']} / val loss: {l['eval']}")
            # generate_sample('Once upon a time')
    
        if l['eval'] < best_val_loss:
            best_val_loss = l['eval']
            print('[CHECKPOINT]: Saving with loss: ', best_val_loss)
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': best_val_loss,
                'iteration': i,
            }, checkpoint_dir + checkpoint_fn)
    
        if wandb_log:
            wandb.log({
                'loss/train': l['train'],
                'loss/val': l['eval'],
                'lr': scheduler.get_last_lr()[0],
            },
            step=i)

        optimizer.zero_grad(set_to_none=True)
        loss.backward()

        nn.utils.clip_grad_norm(model.parameters(), max_norm=grad_clip)

        optimizer.step()
        scheduler.step()

    if wandb_log:
        wandb.finish()

except KeyboardInterrupt:
    print('Training interrupted. Cleaning up......')

finally:
    # Release GPU memory
    print('GPU memory released')
    # sys.exit(0)




# try:
#     for i in tqdm(range(start_iteration, train_iters)):
#         xb, yb = get_batch('train')
#         logits, loss = model(xb, yb)
    
#         # Evaluating loss
#         if (i % eval_interval == 0 or i == train_iters-1):
#             l = calculate_loss()
#             print(f"\n{i}: train loss: {l['train']} / val loss: {l['eval']}")
#             # generate_sample('Once upon a time')
    
#         if l['eval'] < best_val_loss:
#             best_val_loss = l['eval']
#             print('[CHECKPOINT]: Saving with loss: ', best_val_loss)
#             torch.save({
#                 'model_state_dict': model.state_dict(),
#                 'optimizer_state_dict': optimizer.state_dict(),
#                 'loss': best_val_loss,
#                 'iteration': i,
#             }, checkpoint_dir + checkpoint_fn)
    
    
#         if wandb_log:
#             wandb_log({
#                 'loss/train': l['train'],
#                 'loss/val': l['eval'],
#                 'lr': scheduler.get_last_lr()[0],
#             },
#             step = i)

#         optimizer.zero_grad(set_to_none = True)
#         loss.backward()

#         nn.utils.clip_grad_norm(model.parameters(), max_norm = grad_clip)

#         optimizer.step()
#         scheduler.step()

#     if wandb_log:
#         wandb.finish()

# except KeyboardInterrupt:
#     print('Training interrupted. Cleaning up......')

# finally:
#     # Release GPU memory
#     print('GPU memory released')
#     # sys.exit(0)

# # torch.cuda.empty_cache()
# Out:
#   0%|                                                                                                 | 0/100000 [00:00<?, ?it/s]
# Iteration: 0
#
# 0: train loss: 8.375 / val loss: 8.375
# [CHECKPOINT]: Saving with loss:  8.375
# C:\Users\ZGMF-X42S\AppData\Local\Temp\ipykernel_15204\2663719481.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   nn.utils.clip_grad_norm(model.parameters(), max_norm=grad_clip)
#   0%|                                                                                      | 1/100000 [00:02<65:50:08,  2.37s/it]
# Iteration: 1
#   0%|                                                                                      | 2/100000 [00:02<30:48:40,  1.11s/it]
# Iteration: 2
#   0%|                                                                                      | 3/100000 [00:02<20:28:38,  1.36it/s]
# Iteration: 3
#   0%|                                                                                      | 4/100000 [00:03<15:39:44,  1.77it/s]
# Iteration: 4
#   0%|                                                                                      | 5/100000 [00:03<12:48:31,  2.17it/s]
# Iteration: 5
#   0%|                                                                                      | 6/100000 [00:03<11:08:11,  2.49it/s]
# Iteration: 6
#   0%|                                                                                      | 7/100000 [00:04<10:07:41,  2.74it/s]
# Iteration: 7
#   0%|                                                                                       | 8/100000 [00:04<9:24:37,  2.95it/s]
# Iteration: 8
#   0%|                                                                                       | 9/100000 [00:04<9:01:08,  3.08it/s]
# Iteration: 9
#   0%|                                                                                      | 10/100000 [00:04<8:39:32,  3.21it/s]
# Iteration: 10
#   0%|                                                                                      | 11/100000 [00:05<8:23:24,  3.31it/s]
# Iteration: 11
#   0%|                                                                                      | 12/100000 [00:05<8:14:19,  3.37it/s]
# Iteration: 12
#   0%|                                                                                      | 13/100000 [00:05<8:08:04,  3.41it/s]
#   1%|█▏                                                                                  | 1363/100000 [08:28<8:41:02,  3.16it/s]
# Iteration: 1363
#   1%|█▏                                                                                  | 1364/100000 [08:29<8:41:49,  3.15it/s]
# Iteration: 1364
#   1%|█▏                                                                                  | 1365/100000 [08:29<8:37:13,  3.18it/s]
# Iteration: 1365
#   1%|█▏                                                                                  | 1366/100000 [08:29<8:30:04,  3.22it/s]
# Iteration: 1366
#   1%|█▏                                                                                  | 1367/100000 [08:30<8:26:24,  3.25it/s]
# Iteration: 1367
#   1%|█▏                                                                                  | 1368/100000 [08:30<8:26:03,  3.25it/s]
# Iteration: 1368
#   1%|█▏                                                                                  | 1369/100000 [08:30<8:28:01,  3.24it/s]
# Iteration: 1369
#   1%|█▏                                                                                  | 1370/100000 [08:31<8:30:11,  3.22it/s]
# Iteration: 1370
#   1%|█▏                                                                                  | 1371/100000 [08:31<8:28:42,  3.23it/s]
# Iteration: 1371
#   1%|█▏                                                                                  | 1372/100000 [08:31<8:25:53,  3.25it/s]
# Iteration: 1372
#   1%|█▏                                                                                  | 1373/100000 [08:31<8:26:50,  3.24it/s]
# Iteration: 1373
#   1%|█▏                                                                                  | 1374/100000 [08:32<8:22:01,  3.27it/s]
# Iteration: 1374
#   1%|█▏                                                                                  | 1375/100000 [08:32<8:20:11,  3.29it/s]
# Iteration: 1375
#   1%|█▏                                                                                  | 1376/100000 [08:32<8:15:38,  3.32it/s]
# Iteration: 1376
#   1%|█▏                                                                                  | 1377/100000 [08:33<8:21:36,  3.28it/s]
# Iteration: 1377
#   1%|█▏                                                                                  | 1378/100000 [08:33<8:17:18,  3.31it/s]
# Iteration: 1378
#   1%|█▏                                                                                 | 1378/100000 [08:33<10:12:50,  2.68it/s]
# Training interrupted. Cleaning up......
# GPU memory released

# %%
# !nvidia-smi
# Out:
# Mon Oct 28 23:31:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.80                 Driver Version: 546.80       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   81C    P0              79W /  80W |   4201MiB /  6144MiB |     98%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1508    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      8720    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A     10788    C+G   ...App\OmenCommandCenterBackground.exe    N/A      |
# |    0   N/A  N/A     12796    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     15204      C   ...2S\miniconda3\envs\test2\python.exe    N/A      |
# |    0   N/A  N/A     16364    C+G   ...osoft Office\root\Office16\lync.exe    N/A      |
# |    0   N/A  N/A     24476    C+G   ...\DAUM\PotPlayer\PotPlayerMini64.exe    N/A      |
# |    0   N/A  N/A     24720    C+G   ...ft Office\root\Office16\WINWORD.EXE    N/A      |
# |    0   N/A  N/A     29956    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     30916    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# +---------------------------------------------------------------------------------------+
